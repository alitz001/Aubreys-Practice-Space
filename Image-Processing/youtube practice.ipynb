# %% [markdown]
# # <font color = "green">Python : Image Processing

# %% [markdown]
# ## <font color = "red">Method 1</font>
# ## <font color = "blue">Using Pillow (PIL) Module</font>

# %%
# importing PIL Module
from PIL import Image

# Read Image
img = Image.open('H:\WIPP Project\Images\shadow.jpg')

#Display Image
img.show()

# %% [markdown]
# ## <font color = "red">Method 1.2</font>
# ## <font color = "blue">Using Pillow (PIL) with matplotlib Module</font>

# %%
# importing PIL Module
from PIL import Image
#importing matplotlib Module 
import matplotlib.pyplot as plt

# Read Image, which is in the same folder
img = Image.open('H:\WIPP Project\Images\shadow.jpg')

# Using matplotlib module to display the image
plt.imshow(img)

# %% [markdown]
# ## <font color = "red">Method 2</font>
# ## <font color = "blue">Using matplotlib Module</font>

# %%
# importing matplotlib Modules
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Read the image
img = mpimg.imread('H:\WIPP Project\Images\shadow.jpg')

# Display the Image
plt.imshow(img)

# %% [markdown]
# ## <font color = "red">Method 3</font>
# ## <font color = "blue">Using Imageio with matplotlib Module</font>

# %%
# importing imageio Module
import imageio
#importing matplotlib Module
import matplotlib.pyplot as plt

# Read the image by the imageio module
img = imageio.imread('H:\WIPP Project\Images\shadow.jpg')

# Display the image by using matplotlib
plt.imshow(img)

# %% [markdown]
# ## <font color = "red">Method 4</font>
# ## <font color = "blue">Using openCV Module</font>

# %%
# importing openCV-python (cv2) Module 
import cv2 as cv

# Read the image
img = cv.imread('H:\WIPP Project\Images\shadow.jpg',1)
# NB: 1 : cv.IMREAD_COLOR = to load color images, transparency neglected
# 0 : CV.IMREAD_GRAYSCALE = to load images in greyscale mode
# -1: cv.IMREAD_UNCHANGED = to load image including as such alpha channel

# Display image
cv.imshow('windowTitle',img)

# to display image until you press any key in keyboard
cv.waitKey(0)

# to destroy all windows 
cv.destroyAllWindows()
